# %%
#userInput
# name=input("Enter your name:")
# print(name)
# num=input("Enter the number ") #this takes string
# num=int(num)+6
# print(num)
#multiLine String
strring='ram ' \
        'is a bad bad guy'
strring1="harry" \
        " is an as*hole"
strring2='''Who the f*ck is ram and harry?'''
print(strring2,strring,strring1)
# Out:
# Who the f*ck is ram and harry? ram is a bad bad guy harry is an as*hole

# %%
#String and stringMethods
name='pradeep'
print(name)

print(name[1:5])  #start from 1 and go all the way till 5
print(name.upper())
print(name.capitalize()) #first letter capital remeaing small
print(name.count('e'))
print(name.isalnum())
print(name.isdigit())
print(name.isnumeric())
# Out:
# pradeep
# rade
# PRADEEP
# Pradeep
# 2
# True
# False
# False

# %%
#data visualization demo using matplotlib.pyplot and numpy
import matplotlib.pyplot as plt
import numpy as np
xpts=np.array([0,4])
ypts=np.array([0,100])

plt.plot(xpts,ypts)
plt.show()

# %%
#pandas demo that reads .xlsx file
import pandas as pd
df=pd.read_excel("file.xlsx")
print(df)
# Out:
#      0 First Name   Last Name  Gender        Country  Age        Date    Id
# 0    1      Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1    2       Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2    3     Philip        Gent    Male         France   36  21/05/2015  2587
# 3    4   Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4    5    Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5    6     Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6    7       Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7    8    Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    9   Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9   10     Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10  11    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# ...

# %%
#lists
l1=[3,2,45,534,12,1,'f*ck']
print(type(l1))
print(l1)
l1.remove(12)
print(l1)
print(l1.count(2))
l1.remove('f*ck')
l1.sort()
print(l1)
l1.append(45)
print(l1)
l1.extend([23,23,42])
print(l1)
# l1.clear()
# print(l1)
# Out:
# <class 'list'>
# [3, 2, 45, 534, 12, 1, 'f*ck']
# [3, 2, 45, 534, 1, 'f*ck']
# 1
# [1, 2, 3, 45, 534]
# [1, 2, 3, 45, 534, 45]
# [1, 2, 3, 45, 534, 45, 23, 23, 42]

# %%
#tuples
t=(1,4,2,5,2,90,7,1,3)

t.count(1)
#tuple is immutable and hence t[0]=23 shows error
# Out:
# 2

# %%
5#sets method
a={1,2,8,8,2,3,5}
b={'a','e','c','d',10}
print(a)
print(a.pop())
print(a)
a.add(7)
print(a)
a.add(10)
print(a)
print(a.union(b))
print(a.intersection(b))
/#empty set
c=set()
print(c,type(c))
d={}
print(d,type(d))
# Out:
# {1, 2, 3, 5, 8}
# 1
# {2, 3, 5, 8}
# {2, 3, 5, 7, 8}
# {2, 3, 5, 7, 8, 10}
# {2, 3, 5, 7, 8, 10, 'd', 'a', 'e', 'c'}
# {10}
# set() <class 'set'>
# {} <class 'dict'>

# %%
#dictionaries key values pair
dict1={"good":"something comfortable","bad":"something unplesent","1":"One"}
print(dict1,type(dict1))
print(dict1["1"])
print(dict1["bad"])
#methods mutable
dict1["neurology"]="nerves system"
print(dict1);
print(dict1.get("sex"))#prints key is not in dict. none but if dict1["sex"] throws error
print(dict1.keys())
print(dict1.values())
print(dict1.items())
# Out:
# {'good': 'something comfortable', 'bad': 'something unplesent', '1': 'One'} <class 'dict'>
# One
# something unplesent
# {'good': 'something comfortable', 'bad': 'something unplesent', '1': 'One', 'neurology': 'nerves system'}
# None
# dict_keys(['good', 'bad', '1', 'neurology'])
# dict_values(['something comfortable', 'something unplesent', 'One', 'nerves system'])
# dict_items([('good', 'something comfortable'), ('bad', 'something unplesent'), ('1', 'One'), ('neurology', 'nerves system')])

# %%
#Conditional
# if(8<9):
#     print("Yes")
# else:
#     print("No");

    
# age=int(input("Enter your age?"))
# if(age>=18):
#     print("you can have sex")
# elif(age>=15 and age<18):
#     print("you can have sex after few years wait till 18")
# else:
#     print("You are a kid go watch cartoons")
a=2

match a:
    case 1:
        print("Case is 1")
    case 2:
        print("case 2")
    case 3:
        print("case 3")
    case _:
        print("not found")
# Out:
# case 2

# %%
#For Loops
for i in range(5) :
    print(i)
a=[1,2,53,32,12,23]
for arr in a:
    print(arr)
# Out:
# 0
# 1
# 2
# 3
# 4
# 1
# 2
# 53
# 32
# 12
# 23

# %%
#while loops
i=0
while(i<10):
    print("F*ck")
    i+=1
print("F*ck has been executed successfully")
love=4
while(love!=0):
    print("Your life is fu*ked")
    love-=1
# Out:
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck
# F*ck has been executed successfully
# Your life is fu*ked
# Your life is fu*ked
# Your life is fu*ked
# Your life is fu*ked

# %%
#function in python
def greetHello(name,ending):#passing arguments
    print("Hello"+name)
    print("hello")
    print(ending)
print("Executing function...")
greetHello("pradeep",'Thank You')
print('done')
def letterGenerator(name,date):
    st=f"Hi mam, \nThis is {name} and I'm gonna be abscent on {date}"
    print(st)
letterGenerator("Pradeep","12th march")

def average(a,b):
    return (a+b)/2
average(10,10)
# Out:
# Executing function...
# Hellopradeep
# hello
# Thank You
# done
# Hi mam,
# This is Pradeep and I'm gonna be abscent on 12th march
# 10.0

# %%
#Exception Handling
try:
    a=int(input("Enter the number:"))
    print(a+3)
except Exception as e:
    print("Some error occured",e)
# Out:
# Enter the number:89
# 92

# %%
#file handling
s="Ram is bad guy"
#write to file
# with open("test.txt","w") as f:
#     f.write(s)
#next method
# fp=open("text.txt1","w")
# fp.write(s)
# fp.close()

#reading a file
# with open("test.txt","r") as f:
#     s=f.read()
#     print(s)
# f=open("test.txt","r")
# s=f.read()
# print(s)

#appending to file
fp=open("text.txt",'a')
fp.write("Ram is bad guy")
fp.close()

# %%
#Object Oriented Programming
class Employee:
    def __init__(self,name,salary):#constructor
        self.name=name
        self.salary=salary
    def getSalary(self):
        return self.salary
rohan=Employee("Rohan","89390000")
print(rohan.salary)
print(rohan.name)

ram=Employee("ram","893900")
print(ram.salary)
print(ram.name)
# Out:
# 89390000
# Rohan
# 893900
# ram

# %%
#Project : RoboSpeaker
import win32com.client as wincom
if __name__=='__main__':
    print("Welcome to RoboSpeaker 1.1 Created by F*ck")
    speak=wincom.Dispatch("SAPI.SpVoice")
    x=input("Enter what do you want me to pronunce: ")
    speak.speak(f"{x}")
# Out:
# Welcome to RoboSpeaker 1.1 Created by F*ck
# Enter what do you want me to pronunce: hey boy

# %%
#Project :Whether App
import win32com.client as wincom
import requests 
import json
city=input("Enter the name of the city\n")
url=f"https://api.weatherapi.com/v1/current.json?key=b13989793f184149a91141538230103&q={city}"
speak=wincom.Dispatch("SAPI.SpVoice")

r=requests.get(url)
# print(r.text)
json.loads(r.text)
wdic=json.loads(r.text)
temp=wdic["current"]["temp_c"]
print(temp)
speak.speak(f"The temperature of {city} is {temp}")
# Out:
# Enter the name of the city
# kathmandu
# 18.0
# 1

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread("pradeep.jpg", cv2.IMREAD_UNCHANGED)

# Resize the image
resized_image = cv2.resize(image, (int(image.shape[1]*60/100),int(image.shape[1]*70/100)))

# Display the image using matplotlib
plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
#pdf merger
import PyPDF2

pdffiles=["1.pdf","2.pdf"]
merger=PyPDF2.PdfMerger()
for filename in pdffiles:
    pdfFile=open(filename,'rb')
    pdfReader=PyPDF2.PdfReader(pdfFile)
    merger.append(pdfReader)
pdfFile.close()
merger.write('merged.pdf')

# %%
#Attendence system
#Attendences using face_recognition in python

import face_recognition
import cv2
import numpy as np
import csv
from datetime import datetime

video_capture=cv2.VideoCapture(0)

# Load known faces
pradeep_images=face_recognition.load_image_file("faces/pradeep.jpg")
harry_encoding =face_recognition.face_encodings(pradeep_images)[0]

rohan_image=face_recognition.load_image_file("faces/rohan.jpg")
rohan_encoding=face_recognition.face_encodings(rohan_image)[0]

known_face_names=["Pradeep","Rohan"]
known_faces_encodings=[harry_encoding,rohan_encoding]

#list of expected students
students=known_face_names.copy()

face_locations=[]
face_encodings=[]

#Get the current date and time

now =datetime.now()
current_date=now.strftime("%Y-%m-%d")

f=open(f"{current_date}.csv","w+",newline="")
lnwriter=csv.writer(f)

while True:
    _,frame=video_capture.read()
    small_frame=cv2.resize(frame,(0,0),fx=0.25,fy=0.25)
    rgb_small_frame=cv2.cvtColor(small_frame,cv2.COLOR_BGR2RGB)
    #Recognize faces 
    face_locations=face_recognition.face_locations(rgb_small_frame)
    face_encodings=face_recognition.face_encodings(rgb_small_frame,face_locations)

    for face_encoding in face_encodings:
        matches=face_recognition.compare_faces(known_faces_encodings,face_encoding)
        face_distance=face_recognition.face_distance(known_faces_encodings,face_encoding)
        best_match_index=np.argmin(face_distance)

        if(matches[best_match_index]):
            name=known_face_names[best_match_index]
        #if a person is present
        if name in known_face_names:
            font=cv2.FONT_HERSHEY_SIMPLEX
            bottomLeftCornerOfText=(10,100)
            fontScale=1.5
            fontColor=(255,0,0)
            thickness=3
            lineType=2
            cv2.putText(frame,name+" Present",bottomLeftCornerOfText,font,fontScale,fontColor,thickness,lineType)

            if name in students:
                students.remove(name)
                current_time=now.strftime("%H-%M%S")
                lnwriter.writerow([name,current_time])

        cv2.imshow("Attendance",frame)
        if cv2.waitKey(1) & 0xFF== ord('q'):
            break
